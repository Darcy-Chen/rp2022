# %%
import tensorflow as tf
import numpy as np
import torch

# %%
interpreter = tf.lite.Interpreter(model_path="mbv1_1.0_12_90_68.4.tflite")
interpreter.allocate_tensors()

# %%
stuff = interpreter.get_tensor_details()

# %%
stuff
# Out:
# [{'name': 'Const',
#   'index': 0,
#   'shape': array([1, 1, 3], dtype=int32),
#   'shape_signature': array([1, 1, 3], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'ConstantFolding/truediv_recip',
#   'index': 1,
#   'shape': array([1, 1, 3], dtype=int32),
#   'shape_signature': array([1, 1, 3], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'float_image_input',
#   'index': 2,
#   'shape': array([  1, 224, 224,   3], dtype=int32),
#   'shape_signature': array([  1, 224, 224,   3], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Pad',
#   'index': 3,
#   'shape': array([  1, 226, 226,   3], dtype=int32),
#   'shape_signature': array([  1, 226, 226,   3], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Pad/paddings',
#   'index': 4,
#   'shape': array([4, 2], dtype=int32),
#   'shape_signature': array([4, 2], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Pad_1',
#   'index': 5,
#   'shape': array([  1, 114, 114,  64], dtype=int32),
#   'shape_signature': array([  1, 114, 114,  64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Pad_1/paddings',
#   'index': 6,
#   'shape': array([4, 2], dtype=int32),
#   'shape_signature': array([4, 2], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Pad_2',
#   'index': 7,
#   'shape': array([  1,  58,  58, 128], dtype=int32),
#   'shape_signature': array([  1,  58,  58, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Pad_2/paddings',
#   'index': 8,
#   'shape': array([4, 2], dtype=int32),
#   'shape_signature': array([4, 2], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Pad_3',
#   'index': 9,
#   'shape': array([  1,  30,  30, 256], dtype=int32),
#   'shape_signature': array([  1,  30,  30, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Pad_3/paddings',
#   'index': 10,
#   'shape': array([4, 2], dtype=int32),
#   'shape_signature': array([4, 2], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Pad_4',
#   'index': 11,
#   'shape': array([  1,  16,  16, 512], dtype=int32),
#   'shape_signature': array([  1,  16,  16, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Pad_4/paddings',
#   'index': 12,
#   'shape': array([4, 2], dtype=int32),
#   'shape_signature': array([4, 2], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu',
#   'index': 13,
#   'shape': array([  1, 112, 112,  32], dtype=int32),
#   'shape_signature': array([  1, 112, 112,  32], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_1',
#   'index': 14,
#   'shape': array([  1, 112, 112,  32], dtype=int32),
#   'shape_signature': array([  1, 112, 112,  32], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_10',
#   'index': 15,
#   'shape': array([  1,  28,  28, 256], dtype=int32),
#   'shape_signature': array([  1,  28,  28, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_11',
#   'index': 16,
#   'shape': array([  1,  14,  14, 256], dtype=int32),
#   'shape_signature': array([  1,  14,  14, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_12',
#   'index': 17,
#   'shape': array([  1,  14,  14, 512], dtype=int32),
#   'shape_signature': array([  1,  14,  14, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_13',
#   'index': 18,
#   'shape': array([  1,  14,  14, 512], dtype=int32),
#   'shape_signature': array([  1,  14,  14, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_14',
#   'index': 19,
#   'shape': array([  1,  14,  14, 512], dtype=int32),
#   'shape_signature': array([  1,  14,  14, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_15',
#   'index': 20,
#   'shape': array([  1,  14,  14, 512], dtype=int32),
#   'shape_signature': array([  1,  14,  14, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_16',
#   'index': 21,
#   'shape': array([  1,  14,  14, 512], dtype=int32),
#   'shape_signature': array([  1,  14,  14, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_17',
#   'index': 22,
#   'shape': array([  1,  14,  14, 512], dtype=int32),
#   'shape_signature': array([  1,  14,  14, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_18',
#   'index': 23,
#   'shape': array([  1,  14,  14, 512], dtype=int32),
#   'shape_signature': array([  1,  14,  14, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_19',
#   'index': 24,
#   'shape': array([  1,  14,  14, 512], dtype=int32),
#   'shape_signature': array([  1,  14,  14, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_2',
#   'index': 25,
#   'shape': array([  1, 112, 112,  64], dtype=int32),
#   'shape_signature': array([  1, 112, 112,  64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_20',
#   'index': 26,
#   'shape': array([  1,  14,  14, 512], dtype=int32),
#   'shape_signature': array([  1,  14,  14, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_21',
#   'index': 27,
#   'shape': array([  1,  14,  14, 512], dtype=int32),
#   'shape_signature': array([  1,  14,  14, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_22',
#   'index': 28,
#   'shape': array([  1,  14,  14, 512], dtype=int32),
#   'shape_signature': array([  1,  14,  14, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_23',
#   'index': 29,
#   'shape': array([  1,   7,   7, 512], dtype=int32),
#   'shape_signature': array([  1,   7,   7, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_24',
#   'index': 30,
#   'shape': array([   1,    7,    7, 1024], dtype=int32),
#   'shape_signature': array([   1,    7,    7, 1024], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_25',
#   'index': 31,
#   'shape': array([   1,    7,    7, 1024], dtype=int32),
#   'shape_signature': array([   1,    7,    7, 1024], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_26',
#   'index': 32,
#   'shape': array([   1,    7,    7, 1024], dtype=int32),
#   'shape_signature': array([   1,    7,    7, 1024], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_3',
#   'index': 33,
#   'shape': array([ 1, 56, 56, 64], dtype=int32),
#   'shape_signature': array([ 1, 56, 56, 64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_4',
#   'index': 34,
#   'shape': array([  1,  56,  56, 128], dtype=int32),
#   'shape_signature': array([  1,  56,  56, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_5',
#   'index': 35,
#   'shape': array([  1,  56,  56, 128], dtype=int32),
#   'shape_signature': array([  1,  56,  56, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_6',
#   'index': 36,
#   'shape': array([  1,  56,  56, 128], dtype=int32),
#   'shape_signature': array([  1,  56,  56, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_7',
#   'index': 37,
#   'shape': array([  1,  28,  28, 128], dtype=int32),
#   'shape_signature': array([  1,  28,  28, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_8',
#   'index': 38,
#   'shape': array([  1,  28,  28, 256], dtype=int32),
#   'shape_signature': array([  1,  28,  28, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/Relu_9',
#   'index': 39,
#   'shape': array([  1,  28,  28, 256], dtype=int32),
#   'shape_signature': array([  1,  28,  28, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_0/convolution_bias',
#   'index': 40,
#   'shape': array([64], dtype=int32),
#   'shape_signature': array([64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_0/weights/masked_weight',
#   'index': 41,
#   'shape': array([64,  1,  1, 32], dtype=int32),
#   'shape_signature': array([64,  1,  1, 32], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_1/convolution_bias',
#   'index': 42,
#   'shape': array([128], dtype=int32),
#   'shape_signature': array([128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_1/weights/masked_weight',
#   'index': 43,
#   'shape': array([128,   1,   1,  64], dtype=int32),
#   'shape_signature': array([128,   1,   1,  64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_10/convolution_bias',
#   'index': 44,
#   'shape': array([512], dtype=int32),
#   'shape_signature': array([512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_10/weights/masked_weight',
#   'index': 45,
#   'shape': array([512,   1,   1, 512], dtype=int32),
#   'shape_signature': array([512,   1,   1, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_11/convolution_bias',
#   'index': 46,
#   'shape': array([1024], dtype=int32),
#   'shape_signature': array([1024], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_11/weights/masked_weight',
#   'index': 47,
#   'shape': array([1024,    1,    1,  512], dtype=int32),
#   'shape_signature': array([1024,    1,    1,  512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_12/convolution_bias',
#   'index': 48,
#   'shape': array([1024], dtype=int32),
#   'shape_signature': array([1024], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_12/weights/masked_weight',
#   'index': 49,
#   'shape': array([1024,    1,    1, 1024], dtype=int32),
#   'shape_signature': array([1024,    1,    1, 1024], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_2/convolution_bias',
#   'index': 50,
#   'shape': array([128], dtype=int32),
#   'shape_signature': array([128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_2/weights/masked_weight',
#   'index': 51,
#   'shape': array([128,   1,   1, 128], dtype=int32),
#   'shape_signature': array([128,   1,   1, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_3/convolution_bias',
#   'index': 52,
#   'shape': array([256], dtype=int32),
#   'shape_signature': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_3/weights/masked_weight',
#   'index': 53,
#   'shape': array([256,   1,   1, 128], dtype=int32),
#   'shape_signature': array([256,   1,   1, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_4/convolution_bias',
#   'index': 54,
#   'shape': array([256], dtype=int32),
#   'shape_signature': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_4/weights/masked_weight',
#   'index': 55,
#   'shape': array([256,   1,   1, 256], dtype=int32),
#   'shape_signature': array([256,   1,   1, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_5/convolution_bias',
#   'index': 56,
#   'shape': array([512], dtype=int32),
#   'shape_signature': array([512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_5/weights/masked_weight',
#   'index': 57,
#   'shape': array([512,   1,   1, 256], dtype=int32),
#   'shape_signature': array([512,   1,   1, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_6/convolution_bias',
#   'index': 58,
#   'shape': array([512], dtype=int32),
#   'shape_signature': array([512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_6/weights/masked_weight',
#   'index': 59,
#   'shape': array([512,   1,   1, 512], dtype=int32),
#   'shape_signature': array([512,   1,   1, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_7/convolution_bias',
#   'index': 60,
#   'shape': array([512], dtype=int32),
#   'shape_signature': array([512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_7/weights/masked_weight',
#   'index': 61,
#   'shape': array([512,   1,   1, 512], dtype=int32),
#   'shape_signature': array([512,   1,   1, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_8/convolution_bias',
#   'index': 62,
#   'shape': array([512], dtype=int32),
#   'shape_signature': array([512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_8/weights/masked_weight',
#   'index': 63,
#   'shape': array([512,   1,   1, 512], dtype=int32),
#   'shape_signature': array([512,   1,   1, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_9/convolution_bias',
#   'index': 64,
#   'shape': array([512], dtype=int32),
#   'shape_signature': array([512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/contraction_1x1_9/weights/masked_weight',
#   'index': 65,
#   'shape': array([512,   1,   1, 512], dtype=int32),
#   'shape_signature': array([512,   1,   1, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_0/depthwise_bias',
#   'index': 66,
#   'shape': array([32], dtype=int32),
#   'shape_signature': array([32], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_0/depthwise_weights/read',
#   'index': 67,
#   'shape': array([ 1,  3,  3, 32], dtype=int32),
#   'shape_signature': array([ 1,  3,  3, 32], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_1/depthwise_bias',
#   'index': 68,
#   'shape': array([64], dtype=int32),
#   'shape_signature': array([64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_1/depthwise_weights/read',
#   'index': 69,
#   'shape': array([ 1,  3,  3, 64], dtype=int32),
#   'shape_signature': array([ 1,  3,  3, 64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_10/depthwise_bias',
#   'index': 70,
#   'shape': array([512], dtype=int32),
#   'shape_signature': array([512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_10/depthwise_weights/read',
#   'index': 71,
#   'shape': array([  1,   3,   3, 512], dtype=int32),
#   'shape_signature': array([  1,   3,   3, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_11/depthwise_bias',
#   'index': 72,
#   'shape': array([512], dtype=int32),
#   'shape_signature': array([512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_11/depthwise_weights/read',
#   'index': 73,
#   'shape': array([  1,   3,   3, 512], dtype=int32),
#   'shape_signature': array([  1,   3,   3, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_12/depthwise_bias',
#   'index': 74,
#   'shape': array([1024], dtype=int32),
#   'shape_signature': array([1024], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_12/depthwise_weights/read',
#   'index': 75,
#   'shape': array([   1,    3,    3, 1024], dtype=int32),
#   'shape_signature': array([   1,    3,    3, 1024], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_2/depthwise_bias',
#   'index': 76,
#   'shape': array([128], dtype=int32),
#   'shape_signature': array([128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_2/depthwise_weights/read',
#   'index': 77,
#   'shape': array([  1,   3,   3, 128], dtype=int32),
#   'shape_signature': array([  1,   3,   3, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_3/depthwise_bias',
#   'index': 78,
#   'shape': array([128], dtype=int32),
#   'shape_signature': array([128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_3/depthwise_weights/read',
#   'index': 79,
#   'shape': array([  1,   3,   3, 128], dtype=int32),
#   'shape_signature': array([  1,   3,   3, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_4/depthwise_bias',
#   'index': 80,
#   'shape': array([256], dtype=int32),
#   'shape_signature': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_4/depthwise_weights/read',
#   'index': 81,
#   'shape': array([  1,   3,   3, 256], dtype=int32),
#   'shape_signature': array([  1,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_5/depthwise_bias',
#   'index': 82,
#   'shape': array([256], dtype=int32),
#   'shape_signature': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_5/depthwise_weights/read',
#   'index': 83,
#   'shape': array([  1,   3,   3, 256], dtype=int32),
#   'shape_signature': array([  1,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_6/depthwise_bias',
#   'index': 84,
#   'shape': array([512], dtype=int32),
#   'shape_signature': array([512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_6/depthwise_weights/read',
#   'index': 85,
#   'shape': array([  1,   3,   3, 512], dtype=int32),
#   'shape_signature': array([  1,   3,   3, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_7/depthwise_bias',
#   'index': 86,
#   'shape': array([512], dtype=int32),
#   'shape_signature': array([512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_7/depthwise_weights/read',
#   'index': 87,
#   'shape': array([  1,   3,   3, 512], dtype=int32),
#   'shape_signature': array([  1,   3,   3, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_8/depthwise_bias',
#   'index': 88,
#   'shape': array([512], dtype=int32),
#   'shape_signature': array([512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_8/depthwise_weights/read',
#   'index': 89,
#   'shape': array([  1,   3,   3, 512], dtype=int32),
#   'shape_signature': array([  1,   3,   3, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_9/depthwise_bias',
#   'index': 90,
#   'shape': array([512], dtype=int32),
#   'shape_signature': array([512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/depthwise_nxn_9/depthwise_weights/read',
#   'index': 91,
#   'shape': array([  1,   3,   3, 512], dtype=int32),
#   'shape_signature': array([  1,   3,   3, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/final_avg_pool/AvgPool',
#   'index': 92,
#   'shape': array([   1,    1,    1, 1024], dtype=int32),
#   'shape_signature': array([   1,    1,    1, 1024], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/final_dense/MatMul_bias',
#   'index': 93,
#   'shape': array([1000], dtype=int32),
#   'shape_signature': array([1000], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/final_dense/kernel/read/transpose',
#   'index': 94,
#   'shape': array([1000, 1024], dtype=int32),
#   'shape_signature': array([1000, 1024], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/final_dense_1',
#   'index': 95,
#   'shape': array([   1, 1000], dtype=int32),
#   'shape_signature': array([   1, 1000], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/initial_conv/Conv2D_bias',
#   'index': 96,
#   'shape': array([32], dtype=int32),
#   'shape_signature': array([32], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'resnet_model/initial_conv/kernel/read',
#   'index': 97,
#   'shape': array([32,  3,  3,  3], dtype=int32),
#   'shape_signature': array([32,  3,  3,  3], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'sub',
#   'index': 98,
#   'shape': array([  1, 224, 224,   3], dtype=int32),
#   'shape_signature': array([  1, 224, 224,   3], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'truediv',
#   'index': 99,
#   'shape': array([  1, 224, 224,   3], dtype=int32),
#   'shape_signature': array([  1, 224, 224,   3], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': '',
#   'index': 106,
#   'shape': array([27, 32], dtype=int32),
#   'shape_signature': array([27, 32], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': '',
#   'index': 107,
#   'shape': array([32, 64], dtype=int32),
#   'shape_signature': array([32, 64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': '',
#   'index': 108,
#   'shape': array([ 64, 128], dtype=int32),
#   'shape_signature': array([ 64, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': '',
#   'index': 109,
#   'shape': array([128, 128], dtype=int32),
#   'shape_signature': array([128, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': '',
#   'index': 110,
#   'shape': array([128, 256], dtype=int32),
#   'shape_signature': array([128, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': '',
#   'index': 111,
#   'shape': array([256, 256], dtype=int32),
#   'shape_signature': array([256, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': '',
#   'index': 112,
#   'shape': array([256, 512], dtype=int32),
#   'shape_signature': array([256, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': '',
#   'index': 113,
#   'shape': array([512, 512], dtype=int32),
#   'shape_signature': array([512, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': '',
#   'index': 114,
#   'shape': array([512, 512], dtype=int32),
#   'shape_signature': array([512, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': '',
#   'index': 115,
#   'shape': array([512, 512], dtype=int32),
#   'shape_signature': array([512, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': '',
#   'index': 116,
#   'shape': array([512, 512], dtype=int32),
#   'shape_signature': array([512, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': '',
#   'index': 117,
#   'shape': array([512, 512], dtype=int32),
#   'shape_signature': array([512, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': '',
#   'index': 118,
#   'shape': array([ 512, 1024], dtype=int32),
#   'shape_signature': array([ 512, 1024], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': '',
#   'index': 119,
#   'shape': array([1024, 1024], dtype=int32),
#   'shape_signature': array([1024, 1024], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}}]

# %%
weight_tensors_meta = []
weight_tensors = []

for j in range(len(stuff)):
    if "kernel" in stuff[j]['name']:
        weight_tensors_meta.append(stuff[j])
        weight_tensors.append(interpreter.get_tensor(j))
        name = weight_tensors_meta[-1]['name'].split("/")[1]
        print(name, weight_tensors[-1].shape)
        np.save(name + "_kernel.npy",weight_tensors[-1])
#         if "depthwise" not in name:
#             np.save(name + ".npy",weight_tensors[-1].squeeze().transpose())
#         else:
#             np.save(name + ".npy",np.transpose(weight_tensors[-1],[3,0,1,2]))
# Out:
# final_dense (1000, 1024)
# initial_conv (32, 3, 3, 3)

# %%
bias_tensors_meta = []
bias_tensors = []

for j in range(len(stuff)):
    if "bias" in stuff[j]['name']:
        bias_tensors_meta.append(stuff[j])
        bias_tensors.append(interpreter.get_tensor(j))
        name = bias_tensors_meta[-1]['name'].split("/")[1]
        print(name, bias_tensors[-1].shape)
        
        np.save(name + "_bias.npy",bias_tensors[-1].squeeze())
# Out:
# contraction_1x1_0 (64,)
# contraction_1x1_1 (128,)
# contraction_1x1_10 (512,)
# contraction_1x1_11 (1024,)
# contraction_1x1_12 (1024,)
# contraction_1x1_2 (128,)
# contraction_1x1_3 (256,)
# contraction_1x1_4 (256,)
# contraction_1x1_5 (512,)
# contraction_1x1_6 (512,)
# contraction_1x1_7 (512,)
# contraction_1x1_8 (512,)
# contraction_1x1_9 (512,)
# depthwise_nxn_0 (32,)
# depthwise_nxn_1 (64,)
# depthwise_nxn_10 (512,)
# depthwise_nxn_11 (512,)
# depthwise_nxn_12 (1024,)
# depthwise_nxn_2 (128,)
# depthwise_nxn_3 (128,)
# depthwise_nxn_4 (256,)
# depthwise_nxn_5 (256,)
# depthwise_nxn_6 (512,)
# depthwise_nxn_7 (512,)
# depthwise_nxn_8 (512,)
# depthwise_nxn_9 (512,)
# final_dense (1000,)
# initial_conv (32,)

# %%
weight_tensors_meta = []
weight_tensors = []

for j in range(len(stuff)):
    if "weight" in stuff[j]['name']:
        weight_tensors_meta.append(stuff[j])
        weight_tensors.append(interpreter.get_tensor(j))
        name = weight_tensors_meta[-1]['name'].split("/")[1]
        print(name, weight_tensors[-1].shape)
        if "depthwise" not in name:
            np.save(name + ".npy",weight_tensors[-1].squeeze().transpose())
        else:
            np.save(name + ".npy",np.transpose(weight_tensors[-1],[3,0,1,2]))
# Out:
# contraction_1x1_0 (64, 1, 1, 32)
# contraction_1x1_1 (128, 1, 1, 64)
# contraction_1x1_10 (512, 1, 1, 512)
# contraction_1x1_11 (1024, 1, 1, 512)
# contraction_1x1_12 (1024, 1, 1, 1024)
# contraction_1x1_2 (128, 1, 1, 128)
# contraction_1x1_3 (256, 1, 1, 128)
# contraction_1x1_4 (256, 1, 1, 256)
# contraction_1x1_5 (512, 1, 1, 256)
# contraction_1x1_6 (512, 1, 1, 512)
# contraction_1x1_7 (512, 1, 1, 512)
# contraction_1x1_8 (512, 1, 1, 512)
# contraction_1x1_9 (512, 1, 1, 512)
# depthwise_nxn_0 (1, 3, 3, 32)
# depthwise_nxn_1 (1, 3, 3, 64)
# depthwise_nxn_10 (1, 3, 3, 512)
# depthwise_nxn_11 (1, 3, 3, 512)
# depthwise_nxn_12 (1, 3, 3, 1024)
# depthwise_nxn_2 (1, 3, 3, 128)
# depthwise_nxn_3 (1, 3, 3, 128)
# depthwise_nxn_4 (1, 3, 3, 256)
# depthwise_nxn_5 (1, 3, 3, 256)
# depthwise_nxn_6 (1, 3, 3, 512)
# depthwise_nxn_7 (1, 3, 3, 512)
# depthwise_nxn_8 (1, 3, 3, 512)
# depthwise_nxn_9 (1, 3, 3, 512)

# %%
test = torch.Tensor(weight_tensors[1].squeeze().transpose())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 test = torch.Tensor(weight_tensors[1].squeeze().transpose())
#
# NameError: name 'torch' is not defined

# %%
a = weight_tensors[2].squeeze().transpose()

# %%
a = a[np.argsort([len(i) for i in [np.where(a[j])[0] for j in range(512)]])]

# %%
for i in range(512):
    print(np.where(a[i]))

# %%
from matplotlib import pyplot as plt
plt.imshow(a,cmap='seismic')

# %%
depthwise_filters = torch.Tensor(weight_tensors[13]).permute(3,0,1,2)
groupwise_filters = torch.Tensor(weight_tensors[0]).permute(0,3,1,2)
depthwise_bias = torch.Tensor(bias_tensors[13])
groupwise_bias = torch.Tensor(bias_tensors[0])

# %%
bias_tensors[13][10]

# %%
import torch
import torch.nn as nn

# %%
input_image = torch.Tensor(np.random.normal(size=(1,32,112,112)))

intermediate = torch.nn.functional.conv2d(input_image, depthwise_filters, bias=depthwise_bias, stride=1, padding=1, dilation=1, groups=32)
intermediate = torch.nn.functional.relu(intermediate)
result_2 = torch.nn.functional.linear(torch.squeeze(intermediate).permute(1,2,0).contiguous().view(-1,32).unsqueeze(0),torch.squeeze(groupwise_filters),bias=None)
result_1 = torch.nn.functional.conv2d(intermediate,groupwise_filters,bias=groupwise_bias,stride=1,padding=0,dilation=1,groups=1)
result_2 = torch.nn.functional.relu(result_2)
result_1 = torch.nn.functional.relu(result_1)

# %%
torch.sum(result_1) - torch.sum(result_2)

# %%
np.save("input_image.npy",input_image.squeeze().data.numpy())
np.save("depthwise_filters.npy",depthwise_filters.squeeze().data.numpy())
np.save("result.npy",np.transpose(result_2.squeeze().data.numpy()))

# %%
test = result_2.squeeze().data.numpy()

# %%
test = np.transpose(test)

# %%
test[61,12543]

# %%
intermediate.squeeze()[0]

# %%
input_image.shape

# %%
result_1

# %%
padded_in = torch.nn.functional.pad(input_image,(8,8,1,1))
np.save("padded_input_image.npy",padded_in.squeeze().data.numpy())
padded_out = torch.nn.functional.pad(result_1,(8,8,1,1))
np.save("padded_result.npy",padded_out.squeeze().data.numpy())

# %%
padded_in.shape

# %%
result_1

# %%
a = torch.Tensor(np.random.normal(size=(1,3,224,224)))

# %%
m = nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2)

# %%
a.shape

# %%
m(a).shape

# %%
m1 = nn.MaxPool2d(3,2)

# %%
m1(m(a)).shape
